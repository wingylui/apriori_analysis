# %%
import pandas as pd
import numpy as np

# %%
with open("./week1_assign.txt", "r") as file: 
    data = file.readlines()
    dum = []
    file_set = set()
    for row in data:
        dum.append(row.strip().split(";"))
        file_set.update(row.strip().split(";"))

df = pd.DataFrame(dum)
df.shape
# Out:
# (77185, 10)

# %%
# create blank list in the dict
unique_cat = {k: [] for k in file_set} 
for index, row in df.iterrows():
    dum = list(row.values)
    # remove all the items find in the dum list
    set_ = file_set.difference(dum)
    # for loop the dum list and append the key into each list and others not find in dum list will loop through set_ and insert null value
    for key in dum:
        if key != None:
            unique_cat[key].append(True)
        else: 
            break
    for key in set_:
        unique_cat[key].append(False)


unique_cat["Restaurants"]
# Out:
# [True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  ...]

# %%
final_df = pd.DataFrame(unique_cat)

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Extracting the most frequest itemsets via Mlxtend.
# The length column has been added to increase ease of filtering.
frequent_itemsets = apriori(final_df, min_support=0.01, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets["abs support"] = (frequent_itemsets["support"] * df.shape[0]).astype(int)
# printing the frequent itemset
frequent_itemsets
# Out:
#       support                                           itemsets  length  \
# 0    0.013280                            (Professional Services)       1
# 1    0.056073                                             (Bars)       1
# 2    0.019395                                             (Pets)       1
# 3    0.030628                                       (Sandwiches)       1
# 4    0.031301                           (American (Traditional))       1
# ..        ...                                                ...     ...
# 96   0.031392                     (Restaurants, Bars, Nightlife)       3
# 97   0.010028                  (Fast Food, Burgers, Restaurants)       3
# 98   0.010663    (General Dentistry, Dentists, Health & Medical)       3
# 99   0.018540  (Hotels & Travel, Hotels, Event Planning & Ser...       3
# 100  0.014744              (Fashion, Shopping, Women's Clothing)       3
#
#      abs support
# 0           1025
# 1           4328
# 2           1497
# 3           2364
# 4           2416
# ..           ...
# 96          2423
# 97           774
# 98           823
# 99          1430
# 100         1138
#
# [101 rows x 4 columns]

# %%
## convert the forzenset into list
item_list  = []
abs_support_list = []
for index, row in frequent_itemsets.iterrows():
    item_list.append(list(row["itemsets"]))
    abs_support_list.append(row["abs support"])

# %%
result_string = str()
for n in range(len(item_list)):
    item_str = str()
    result_string = str(result_string) + f"{abs_support_list[n]}:{item_list[n][0]}\n"
result_string
# Out:
# "1025:Professional Services\n4328:Bars\n1497:Pets\n2364:Sandwiches\n2416:American (Traditional)\n818:Sports Bars\n2657:Pizza\n2851:Fast Food\n1195:Dentists\n1586:Home & Garden\n1430:Hotels\n2495:Hotels & Travel\n870:Pet Services\n874:Pubs\n875:Financial Services\n25071:Restaurants\n1018:Ice Cream & Frozen Yogurt\n2271:Arts & Entertainment\n11233:Shopping\n2515:Mexican\n1115:Bakeries\n1150:Specialty Food\n1442:Fitness & Instruction\n3468:Local Services\n2975:Event Planning & Services\n4785:Home Services\n2199:Coffee & Tea\n1694:Doctors\n1002:Cafes\n9250:Food\n1716:Auto Repair\n2091:Hair Salons\n798:Sushi Bars\n6583:Beauty & Spas\n5088:Nightlife\n1424:Grocery\n1424:Real Estate\n3078:Fashion\n1774:Burgers\n1629:Chinese\n1369:Breakfast & Brunch\n1848:Italian\n3103:Active Life\n1593:American (New)\n1138:Women's Clothing\n5120:Health & Medical\n823:General Dentistry\n4208:Automotive\n848:Japanese\n1667:Nail Salons\n818:Bars\n874:Bars\n2423:Restaurants\n4328:Bars\n870:Pets\n2364:Restaurants\n2416:Restaurants\n818:Nightlife\n2657:Restaurants\n2851:Fast Food\n774:Fast Food\n1195:Dentists\n823:General Dentistry\n1586:Home & Garden\n1430:Hotels\n1430:Hotels\n1471:Hotels & Travel\n874:Pubs\n2515:Restaurants\n1002:Restaurants\n2101:Restaurants\n798:Restaurants\n2533:Restaurants\n1774:Restaurants\n1629:Restaurants\n1369:Restaurants\n1848:Restaurants\n1593:Restaurants\n848:Restaurants\n1018:Ice Cream & Frozen Yogurt\n3078:Fashion\n1138:Shopping\n1115:Food\n1150:Food\n1442:Fitness & Instruction\n1424:Real Estate\n2199:Food\n1694:Doctors\n1424:Food\n1716:Automotive\n2091:Beauty & Spas\n1667:Beauty & Spas\n1138:Fashion\n823:General Dentistry\n818:Bars\n874:Bars\n2423:Restaurants\n774:Fast Food\n823:General Dentistry\n1430:Hotels & Travel\n1138:Fashion\n"

# %%
with open('./week1_assign_results.txt', 'w') as f:
    f.writelines(result_string)

# %%
result_string = str()
for n in range(len(item_list)):
    if len(item_list[n]) >= 2 :
        item_str = str()
        if len(item_list[n]) >= 2 :
            for m in range(len(item_list[n])):
                if m == 0:
                    item_str = f"{item_list[n][m]}"
                else:
                    item_str = f"{item_str};{item_list[n][m]}"
        else:
            pass
            # itme_str = str(item_list[n][0])
        result_string = str(result_string) + f"{abs_support_list[n]}:{item_str}\n"
result_string
# Out:
# "818:Bars;Sports Bars\n874:Bars;Pubs\n2423:Restaurants;Bars\n4328:Bars;Nightlife\n870:Pets;Pet Services\n2364:Restaurants;Sandwiches\n2416:Restaurants;American (Traditional)\n818:Nightlife;Sports Bars\n2657:Restaurants;Pizza\n2851:Fast Food;Restaurants\n774:Fast Food;Burgers\n1195:Dentists;Health & Medical\n823:General Dentistry;Dentists\n1586:Home & Garden;Shopping\n1430:Hotels;Hotels & Travel\n1430:Hotels;Event Planning & Services\n1471:Hotels & Travel;Event Planning & Services\n874:Pubs;Nightlife\n2515:Restaurants;Mexican\n1002:Restaurants;Cafes\n2101:Restaurants;Food\n798:Restaurants;Sushi Bars\n2533:Restaurants;Nightlife\n1774:Restaurants;Burgers\n1629:Restaurants;Chinese\n1369:Restaurants;Breakfast & Brunch\n1848:Restaurants;Italian\n1593:Restaurants;American (New)\n848:Restaurants;Japanese\n1018:Ice Cream & Frozen Yogurt;Food\n3078:Fashion;Shopping\n1138:Shopping;Women's Clothing\n1115:Food;Bakeries\n1150:Food;Specialty Food\n1442:Fitness & Instruction;Active Life\n1424:Real Estate;Home Services\n2199:Food;Coffee & Tea\n1694:Doctors;Health & Medical\n1424:Food;Grocery\n1716:Automotive;Auto Repair\n2091:Beauty & Spas;Hair Salons\n1667:Beauty & Spas;Nail Salons\n1138:Fashion;Women's Clothing\n823:General Dentistry;Health & Medical\n818:Bars;Nightlife;Sports Bars\n874:Bars;Pubs;Nightlife\n2423:Restaurants;Bars;Nightlife\n774:Fast Food;Burgers;Restaurants\n823:General Dentistry;Dentists;Health & Medical\n1430:Hotels & Travel;Hotels;Event Planning & Services\n1138:Fashion;Shopping;Women's Clothing\n"

# %%
with open('./week1_assign_results_itemsets.txt', 'w') as f:
    f.writelines(result_string)
